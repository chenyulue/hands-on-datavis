# %% [markdown]
# This practice comes from [2023 Week 13 | Power BI: Create a connected scatterplot with image markers](https://workout-wednesday.com/pbi-2023-w13/).

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
file_path = './datasets/KyotoFullFlower7.xlsx'
data = pd.read_excel(file_path, skiprows=25, ).dropna()
data['date_time'] = pd.to_datetime(data['Full-flowering date'], format='%m%d')
data.head()
# Out:
# C:\Users\chenyulue\mambaforge\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11  812                       92.0                401.0          1.0
# 14  815                      105.0                415.0          1.0
# 30  831                       96.0                406.0          1.0
# 50  851                      108.0                418.0          1.0
# 52  853                      104.0                414.0          1.0
#
#     Data type code          Reference Name  date_time
# 11             2.0              NIHON-KOKI 1900-04-01
# 14             2.0              NIHON-KOKI 1900-04-15
# 30             2.0              NIHON-KOKI 1900-04-06
# 50             2.0  MONTOKUTENNO-JITSUROKU 1900-04-18
# 52             2.0  MONTOKUTENNO-JITSUROKU 1900-04-14

# %%
data.isna().sum()
# Out:
# AD                           0
# Full-flowering date (DOY)    0
# Full-flowering date          0
# Source code                  0
# Data type code               0
# Reference Name               0
# dtype: int64

# %%
import matplotlib.path as mpath
import matplotlib.patches as patches

# Cherry path
verts = np.array([
    (0.002, 1.014), # M
    (-0.546, 0.762), (0, 0), # Q
    (-0.516, 0.669), (-0.972, 0.336),
    (-0.883, -0.174), (0, 0),
    (-0.761, -0.166), (-0.647, -0.706),
    (-0.052, -0.739), (0, 0),
    (0.015, -0.735), (0.605, -0.739),
    (0.757, -0.183), (0, 0),
    (0.812, -0.174), (0.943, 0.315),
    (0.511, 0.618), (0, 0),
    (0.524, 0.76), (0.002, 1.014),
    (0.002, 1.014)])
codes = [1] + [3] * 20 + [79]

cherry = mpath.Path(verts, codes)

fig, ax = plt.subplots()
patch = patches.PathPatch(cherry, facecolor='orange', lw=1)
ax.add_patch(patch)
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
plt.show()

# %%
import matplotlib.image as image
import matplotlib.dates as mdates

img = image.imread('./datasets/cherry_bg.png')

fig, ax = plt.subplots(figsize=(10, 6.18), layout='constrained')
# ax.imshow(img, resample=True, origin='lower')
ax.plot(data['AD'], data['date_time'], marker=cherry,  c='k', mew=0.01, mfc='#DE4D74', mec='#DE4D74', ms=10)

date_fmt = mdates.DateFormatter('%b %#d') # Reference https://stackoverflow.com/questions/9525944/python-datetime-formatting-without-zero-padding
ax.yaxis.set_major_formatter(date_fmt)

font = 'Lucida Calligraphy'
ax.set_ylabel('Flowering Date', fontfamily=font)
ax.set_xlabel('Year', fontfamily=font)

ax.spines[:].set_visible(False)
ax.tick_params(left=False, bottom=False)

for xticklabel, yticklabel in zip(ax.get_xticklabels(), ax.get_yticklabels()):
    xticklabel.set_fontfamily(font)
    yticklabel.set_fontfamily(font)
    
# Add a image as a background
bg_ax = fig.add_axes((0,0,1,1))
bg_ax.set_zorder(-1)
bg_ax.imshow(img, aspect='auto')
bg_ax.spines[:].set_visible(False)
bg_ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)

# Make the Axes background transparent
ax.patch.set_alpha(0)

# Add figure title and description
fontsize=16
offset = 5
ax.annotate('When the cherry blossoms bloom', xy=(0, 1), xytext=(offset, -offset), 
            xycoords=fig.transFigure, textcoords='offset points', fontsize=fontsize, fontfamily=font,
            va='top', ha='left')
ax.annotate('Full-flowering dates of the Japanese cherry (Prunus jamasakura) in Kyoto, Japan\nfor years spanning 812 to 2015',
            xy=(0, 1), xytext=(offset, -fontsize-offset-4), fontfamily=font,
            xycoords=fig.transFigure, textcoords='offset points', va='top', ha='left')

ax.annotate('#2023 Week 13 | Solution by Chenyu Lue', xy=(1, 0), xytext=(-offset, offset), 
            fontsize=8, color='w', fontfamily=font,
            xycoords=fig.transFigure, textcoords='offset points', va='bottom', ha='right')

fig.savefig('pbi-2023-w13.png', bbox_inches='tight', dpi=150)

# %%
ax.get_position()
# Out:
# Bbox([[0.08831977777777779, 0.08971646889608055], [0.995833, 0.993257281553398]])
